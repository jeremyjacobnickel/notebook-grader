# %% [markdown]
# <center>
#     <hr style="height: 1.5pt; border: none; background-color: black; width: 100%;">
#     <br>
#     <font size="6"><b>Grundlagen der Programmierung</b></font>
#     <br><br>
#     <font size="3">
#         Prof. Dr.-Ing. Michael Thiel<br>
#         Labor für Technische Informatik im Maschinenbau<br>
#         Fachbereich Maschinenbau<br>
#         FH Münster
#     </font>
#     <br><br>
#     <hr style="height: 1.5pt; border: none; background-color: black; width: 100%;">
# </center>

# %% [markdown]
# # 1. Praktikum

# %% [markdown]
# ## 1. Aufgabe: Arithmetische Operationen
#
# Berechnen Sie folgende Werte und speichern Sie diese in den Variablen `a` bzw. `b`. Geben Sie das Ergebnis mit `print` aus.
#
# - a) $\quad a = 12\cdot 12 + 12$
# - b) $\quad b = \sqrt{256}$
#
# Was passiert bei folgender Berechnung?
#
# - c) $\frac{1}{0}$

# %%
Test123 dieser Code kann nicht ausgeführt werden

# %% [markdown]
# ## 2. Aufgabe: Transzendente Funktionen
#
# Berechnen Sie folgende Terme und speichern Sie diese in den Variablen `a`, `b` und `c`. Geben Sie das Ergebnis mit `print` aus.
#
# - a) $\quad a = \sin(0)$
# - b) $\quad b = \sin(\pi)$
# - c) $\quad c = \cos(\pi)$
# - d) Warum sind die Ergebnisse von a) und b) nicht identisch? Wählen Sie in Leukipp die korrekte Antwort aus.
#
# **Hinweis:**
#
# - Nutzen Sie die transzendenten Funktionen ($\sin, \cos$, etc.) aus `numpy`.
# - Die Konstante $\pi$ ist in `numpy` definiert. Diese muss genutzt werden, damit die Aufgabe von Leukipp als *richtig* erkannt wird.

# %% [markdown]
# ## 3. Aufgabe: Rechnen mit Variablen
#
# Weisen Sie den Variablen `x` und `y` die Werte `10` bzw. `4` zu. Berechnen Sie mit diesen Werten folgende Terme und speichern Sie diese in den Variablen `a`, $\ldots$, `e`. Geben Sie das Ergebnis mit `print` aus:
#
# - a) $\quad a = 10\cdot x$
# - b) $\quad b = 10^x$
# - c) $\quad c = 2\cdot x - 3\cdot y$
# - d) $\quad d = \frac{x}{y}$
#
# Importieren Sie das Modul `math` mit `import math` und verwenden Sie `math.factorial` zur Berechnung der Fakultät.
#
# - e) $\quad e = (x-y)!$

# %% [markdown]
# ## 4. Aufgabe: Modulo-Operator

# %% [markdown]
# Ein Schreiner möchte einen Holzbalken der Länge $l=2,\!2\,\text{m}$ in Stücke der Länge $s=42\,\text{cm}$ schneiden.
#
# - a) Wie viele Stücke kann er aus dem Balken schneiden? Speichern Sie das Ergebnis in einer Variablen `n`.
# - b) Wie viele Zentimeter Verschnitt hat er? Speichern Sie das Ergebnis in einer Variablen `v`.

# %% [markdown]
# ## 5. Aufgabe: Berechnen Sie...

# %% [markdown]
# Berechnen Sie folgende Ausdrücke. Speichern Sie die Ergebnisse in den Variablen `a` bis `e`. Geben Sie die Ergebnisse jeweils mit `print` aus.
#
# - **a)** $$a = \frac{14.5 + 2.8^3}{\sqrt{19.2 + \frac{4.5}{0.8^2}}} + 12.4 \cdot (5.1 - 2.9)^4$$
#
# - **b)** $$b = \sin(45^\circ) \cdot \cos(30^\circ) + \frac{\tan(60^\circ)}{\sqrt{1 + \sin^2(15^\circ)}}$$
#
# - **c)** $$c = \mathrm e^{\frac{-4.2}{1.5}} \cdot \ln(100) + \log_{10}(250 \cdot \sqrt{\mathrm e^3})$$
#
# - **d)** $$d = \sqrt[3]{ \frac{(15.2^2 - 4.8) \cdot \pi}{\log_{10}(1000) + \mathrm e^{2.1}} } \cdot \left( \frac{1}{ \frac{1}{2.5} + \frac{1}{3.8} } \right)^{1.5}$$
#
# - **e)** $$e = \frac{\sqrt[3]{\frac{\sin(60^\circ)^2 + \cos(60^\circ)^2}{\ln(50) \cdot \log_{10}(100)}} \cdot e^{\frac{2.5}{1.2}}}{\left( \frac{15.8 \cdot \pi}{\sqrt{144}} \right)^{-0.5} + \left( \frac{\sqrt{e^4 + 2 \cdot \pi}}{\tan(60^\circ) + \frac{4.2}{0.8^2}} \right)^2} \cdot \sqrt{\frac{(12.5^3 - 4.2) \cdot \ln(e^2)}{ \log_{10}(1000) + \sqrt[4]{16} }}$$
#
# **Hinweis:**
#
# `np.sqrt`, `np.cbrt`, `np.deg2rad`, `np.tan`, `np.sin`, `np.cos`, `np.log`, `np.log10`, `np.exp`, `np.pi`

# %% [markdown]
# ## 6. Aufgabe: Schwenkkran
#
# Ein Schwenkkran hebt eine Last $m$ an einem Seil hoch. Der Ausleger hat die Länge $L$ und ist unter einem Winkel $\alpha$ zur Horizontalen geneigt.
#
# 1. Initialisieren Sie folgende Konstanten als Python-Variablen:
#     $$
#     \begin{aligned}
#         \text{Lastmasse}\quad&& m &:= 1\,250\,\mathrm{kg} \\
#         \text{Erdbeschleunigung}\quad&& g &:= 9.81\,\mathrm{m/s}^2 \\
#         \text{Auslegerlänge}\quad&& L &:= 5.5\,\mathrm{m} \\
#         \text{Neigungswinkel}\quad&& \alpha &:= 35^\circ
#     \end{aligned}
#     $$
#
# Die Gewichtskraft soll in ihre Komponenten zerlegt werden.
#
# 2. Berechnen Sie die Gewichtskraft $F_\mathrm g$ der Last und speichern sie diese in einer Variablen `F_g`.
# 3. Speichern Sie den Winkel $\alpha$ in Radiant in einer Variablen `alpha_rad`.
# 4. Zerlegen Sie die Gewichtskraft in eine Komponente parallel zum Ausleger $F_\mathrm{par}$ und eine Komponente senkrecht (engl.: *perpendicular*) zum Ausleger $F_\mathrm{perp}$. Verwenden Sie die Variable `alpha_rad`. Speichern Sie die Werte in den Variablen `F_par` und `F_perp`.
#
# Die senkrechte Kraft $F_\mathrm{perp}$ erzeugt eine Biegebeanspruchung. Der Ausleger ist für eine maximale senkrechte Belastung von $F_\mathrm{perp,max}$ von $11\,000\,\mathrm N$ ausgelegt.
#
# 5. Speichern Sie den Wert $F_\mathrm{perp,max}$ in einer Variablen `F_perp_max`.
# 6. Geben Sie mit `print` "eingehalten" aus, wenn die Spezifikationen eingehalten werden, andernfalls "nicht eingehalten".
#
# Die Last soll mit maximaler Beschleunigung angehoben werden.
#
# 7. Berechnen Sie die maximale beschleunigende Kraft, welche unter Einhaltung der Spezifikationen möglich ist. Speichern Sie das Ergebnis in einer Variablen `F_a`.
# 8. Berechnen Sie, um wie viele Meter die Last nach zwei Sekunden angehoben wurde und speichern Sie den Wert in einer Variablen `s`. Nutzen Sie:
#
#     $$
#     \begin{aligned}
#     s(t) &= \frac{1}{2}\cdot a\cdot t^2 \\
#     \\
#     a &\colon \text{Beschleunigung} \\
#     s &\colon \text{Strecke} \\
#     t &\colon \text{Zeit}
#     \end{aligned}
#     $$
#
# **Hinweis:**
#
# - zu 4.: `np.sin`, `np.cos`
# - zu 8.: $F = m\cdot a$

# %% [markdown]
# ## 7. Aufgabe: Vibe Coding
#
# In der Praxis müssen Berechnungen visualisiert werden, um sie für Dritte (Prüfingenieure, Kunden) verständlich zu machen. Ihre Aufgabe ist es, mittels Vibe Coding Python-Code zu generieren, der eine maßstäbliche technische Zeichnung des Schwenkkrans aus Aufgabe 6 erstellt.
#
# An die Grafik werden folgende Anforderungen gestellt:
#
# - Darstellung unter Verwendung der Python-Pakete *numpy* und *matplotlib*.
# - Bemaßung mit $\alpha$, $L$, $m$.
# - Vektorpfeile für die Kräfte $F_\mathrm g$, $F_\mathrm{perp}$, $F_\mathrm{par}$.
# - Der Ausleger ist um 35° nach oben geneigt.
