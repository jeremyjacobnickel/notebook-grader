# %% [markdown]
# # 5. Praktikum – Grundlagen der Programmierung
#
# Bearbeiten Sie die Aufgaben direkt in den jeweils folgenden Codezellen. Die Unit-Tests werden lokal über die VS-Code-Extension ausgeführt.

# %%
import numpy as np

# %% [markdown]
# ## 1. Aufgabe: Fakultät
#
# Implementieren Sie die Fakultät einmal iterativ und einmal rekursiv. Für `0` soll `1` zurückgegeben werden. Für negative Zahlen muss `ValueError` ausgelöst werden.

# %% [markdown]
# ### a) Iterative Fakultät
# Implementieren Sie `factorial_iter(number)` ohne Rekursion.

# %%
def factorial_iter(number):
    # TODO: iterative Fakultät implementieren
    raise NotImplementedError("Aufgabe 1a noch offen")

# %% [markdown]
# ### b) Rekursive Fakultät
# Implementieren Sie `factorial_rec(number)` rekursiv.

# %%
def factorial_rec(number):
    # TODO: Rekursionsanfang und Rekursionsschritt implementieren
    raise NotImplementedError("Aufgabe 1b noch offen")

# %% [markdown]
# ## 2. Aufgabe: Laplacescher Entwicklungssatz
#
# Berechnen Sie die Determinante einer Matrix rekursiv über den Laplaceschen Entwicklungssatz.

# %% [markdown]
# ### a) Matrix erzeugen
# Definieren Sie `A = np.random.default_rng(seed=124823).random((5,5))`.

# %%
A = None  # TODO

# %% [markdown]
# ### b) Matrixelemente
# Weisen Sie `a_00` und `a_12` die Elemente `A[0,0]` bzw. `A[1,2]` zu.

# %%
a_00 = None
a_12 = None

# %% [markdown]
# ### c) Untermatrix
# Implementieren Sie `submatrix(A, i, j)`, die Zeile `i` und Spalte `j` entfernt. Definieren Sie anschließend `A_00 = submatrix(A, 0, 0)` und `A_12 = submatrix(A, 1, 2)`.

# %%
def submatrix(A, i, j):
    raise NotImplementedError("Aufgabe 2c noch offen")

A_00 = None
A_12 = None

# %% [markdown]
# ### d) Determinante nach Laplace
# Implementieren Sie `det_laplace(A)` rekursiv. Der Basisfall ist eine 1x1-Matrix. Berechnen Sie anschließend `det_A = det_laplace(A)`.

# %%
def det_laplace(A):
    raise NotImplementedError("Aufgabe 2d noch offen")

det_A = None

# %% [markdown]
# ## 3. Aufgabe: Das Echo
#
# Die Eingabe `Das Echo` soll zu `D-A-S DAS das ... E-C-H-O ECHO echo` führen.

# %% [markdown]
# ### a) Satzzeichen entfernen
# Implementieren Sie `remove_punctuation(sentence)` für die Satzzeichen `!?.,`.

# %%
def remove_punctuation(sentence):
    raise NotImplementedError("Aufgabe 3a noch offen")

# %% [markdown]
# ### b) Wortecho
# Implementieren Sie `echo_word(word)`. Beispiel: `Echo` → `E-C-H-O ECHO echo`.

# %%
def echo_word(word):
    raise NotImplementedError("Aufgabe 3b noch offen")

# %% [markdown]
# ### c) Satzecho
# Implementieren Sie `echo(sentence)`. Verwenden Sie dafür `remove_punctuation` und `echo_word`. Einzelne Wortechos werden mit ` ... ` getrennt.

# %%
def echo(sentence):
    raise NotImplementedError("Aufgabe 3c noch offen")

# %% [markdown]
# ## 4. Aufgabe: Insertion-Sort
#
# Implementieren Sie `insertion_sort(values)`. Erzeugen Sie eine neue sortierte Liste. Iterieren Sie über die Eingangsliste und suchen Sie in einer inneren Schleife die Einfügeposition. Verwenden Sie `.insert` für das Einfügen vor einem größeren Element und `.append`, wenn das Element ans Ende gehört. Verwenden Sie weder `sorted` noch `.sort`.

# %%
def insertion_sort(values):
    """Sortiere die übergebene Liste aufsteigend und gib eine neue Liste zurück."""
    raise NotImplementedError("Aufgabe 4 noch offen")
